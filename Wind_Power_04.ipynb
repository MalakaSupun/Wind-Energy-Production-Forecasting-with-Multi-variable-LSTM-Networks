# %%
import pandas as pd
import warnings
import matplotlib.pyplot as plt
import numpy as np

warnings.filterwarnings("ignore")

# Load the dataset
dp = pd.read_csv("Data/T1.csv")
# dp.describe()
# df.head()

# %%
df = dp[:10000]

# %%
dp.head()
# Out:
#           Date/Time  ...  Wind Direction (°)
# 0  01 01 2018 00:00  ...          259.994904
# 1  01 01 2018 00:10  ...          268.641113
# 2  01 01 2018 00:20  ...          272.564789
# 3  01 01 2018 00:30  ...          271.258087
# 4  01 01 2018 00:40  ...          265.674286
#
# [5 rows x 5 columns]

# %%
df['Date/Time'] = pd.to_datetime(df['Date/Time'], format="%d %m %Y %H:%M")
df['Month'] = df['Date/Time'].dt.month
df['Week'] = df['Date/Time'].dt.isocalendar().week
df['day'] = df['Date/Time'].dt.day
df['Hour'] = df['Date/Time'].dt.hour
df['Min'] = df['Date/Time'].dt.minute

# df.head(4)

# %%
All_data=df.drop(columns=['Date/Time'])
# All_data.head()
D=np.array(All_data)
# D

# %%
# D

# %%
# Define features and target
target_column = 'LV ActivePower (kW)'  # Assuming 'Power' is the column to predict
target = D[:, 0]
features = np.delete(D, 8, axis=1)

# %%
features = D[:,:]
print(target.shape ,features.shape )
# Out:
# (10000,) (10000, 9)

# %%
plt.figure(figsize=(16,6))
plt.plot(target,'r',label='train')
plt.show()

# %%
# features

# %%
from sklearn.preprocessing import MinMaxScaler

# Initialize the scaler and fit to the dataset
scaler_01 = MinMaxScaler()
features_scaled = scaler_01.fit_transform(features)

# %%
scaler_02 = MinMaxScaler()
W=target.reshape(-1, 1)
W
target_scaled = scaler_02.fit_transform(W)

# %%
# target_scaled

# %%
# import pandas as pd
# from sklearn.impute import KNNImputer
# from sklearn.preprocessing import StandardScaler

# # Load your dataset
# # data = pd.read_csv("wind_turbine_data.csv")

# # Separate timestamp column if needed
# timestamps = df['Date']  # Assuming your timestamp column is named 'Date'
# data = df.drop(columns=['Date'])

# # Optional: Scale the data before imputation (especially useful if features have different scales)
# scaler = StandardScaler()
# data_scaled = pd.DataFrame(scaler.fit_transform(data), columns=data.columns)

# # Initialize and apply KNNImputer
# imputer = KNNImputer(n_neighbors=5)
# data_imputed = imputer.fit_transform(data_scaled)  # Returns a NumPy array

# # Convert back to DataFrame and revert scaling if needed
# data_imputed = pd.DataFrame(data_imputed, columns=data.columns)
# data_imputed = pd.DataFrame(scaler.inverse_transform(data_imputed), columns=data.columns)

# # Reattach timestamp column
# data_imputed['Date'] = timestamps

# %%
timesteps = 4  # Number of past time steps to include

X, y = [], []
for i in range(timesteps, len(features_scaled)):
    X.append(features_scaled[i - timesteps:i])
    y.append(target_scaled[i])

X, y = np.array(X), np.array(y)

# %%
train_size = int(0.8 * len(X))
X_train, X_test = X[:train_size], X[train_size:]
y_train, y_test = y[:train_size], y[train_size:]

# %%
from matplotlib import pyplot as plt

test_x_range=np.arange(train_size ,len(X),1)
#test_x_range is an array of values between 1000-1208
plt.figure(figsize=(16,6))
plt.plot(scaler_02.inverse_transform(y_train),'r',label='train')
plt.plot(test_x_range,scaler_02.inverse_transform(y_test),'b',label='test')
plt.xlabel('Date')
plt.ylabel('Power_Curve (KWh)')
plt.show()

# %%
import tensorflow.keras.backend as K

def r_squared(y_true, y_pred):
    ss_res = K.sum(K.square(y_true - y_pred))
    ss_tot = K.sum(K.square(y_true - K.mean(y_true)))
    return 1 - ss_res / (ss_tot + K.epsilon())

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, Attention, Input
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam

# Define input
inputs = Input(shape=(X_train.shape[1], X_train.shape[2]))

# First LSTM layer
lstm1 = LSTM(48, return_sequences=True)(inputs)
dropout1 = Dropout(0.2)(lstm1)

# Second LSTM layer
lstm2 = LSTM(48, return_sequences=False)(dropout1)
dropout2 = Dropout(0.2)(lstm2)

# Attention Layer
attention = Attention()([dropout2, dropout2])  # Keys and values are the same in this case

# Output layer
dense = Dense(1)(attention)

# Build the model
model = Model(inputs, dense)

# Compile the model
opt = Adam(0.0001, clipnorm=1.0)
model.compile(optimizer=opt, loss='mean_squared_error', metrics=['mae', 'mse'])

# Model summary
model.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_3 (InputLayer)           [(None, 4, 9)]       0           []
#
#  lstm_8 (LSTM)                  (None, 4, 48)        11136       ['input_3[0][0]']
#
#  dropout_6 (Dropout)            (None, 4, 48)        0           ['lstm_8[0][0]']
#
#  lstm_9 (LSTM)                  (None, 48)           18624       ['dropout_6[0][0]']
#
#  dropout_7 (Dropout)            (None, 48)           0           ['lstm_9[0][0]']
#
#  attention_4 (Attention)        (None, 48)           0           ['dropout_7[0][0]',
#                                                                   'dropout_7[0][0]']
#
#  dense_3 (Dense)                (None, 1)            49          ['attention_4[0][0]']
#
# ==================================================================================================
# Total params: 29,809
# Trainable params: 29,809
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, Attention
from tensorflow.keras.optimizers import Adam,SGD

# # Define the LSTM model architecture
model = Sequential()
model.add(LSTM(48, return_sequences=True, input_shape=(X_train.shape[1], X_train.shape[2])))
model.add(Dropout(0.2))  # Dropout layer to prevent overfitting


model.add(LSTM(48, return_sequences=False))
model.add(Dropout(0.2))

# model.add(Dense(25, activation='relu'))
model.add(Dense(1))  # Output layer for regression (predicting power output)

opt = Adam(0.0001, clipnorm=1.0)
# # Compile the model
# model.compile(optimizer=opt, loss='mean_squared_error',metrics=['mae','mse',r_squared])
model.compile(optimizer=opt, loss='mean_squared_error',metrics=['mae','mse'])
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_4 (LSTM)               (None, 4, 48)             11136
#
#  dropout_2 (Dropout)         (None, 4, 48)             0
#
#  lstm_5 (LSTM)               (None, 48)                18624
#
#  dropout_3 (Dropout)         (None, 48)                0
#
#  dense_1 (Dense)             (None, 1)                 49
#
# =================================================================
# Total params: 29,809
# Trainable params: 29,809
# Non-trainable params: 0
# _________________________________________________________________

# %%
# from tensorflow.keras.models import Sequential
# from tensorflow.keras.layers import LSTM, Dense, Dropout, BatchNormalization

# # Define the LSTM model architecture
# model = Sequential()
# model.add(LSTM(128, return_sequences=True, input_shape=(X_train.shape[1], X_train.shape[2])))
# model.add(BatchNormalization())
# model.add(Dropout(0.3))  # Dropout layer to prevent overfitting

# model.add(LSTM(units=96,return_sequences=True))
# model.add(BatchNormalization())
# model.add(Dropout(0.3))

# model.add(LSTM(units=64,return_sequences=True))
# model.add(BatchNormalization())
# model.add(Dropout(0.2))

# model.add(LSTM(units=32,return_sequences=False))
# model.add(BatchNormalization())
# model.add(Dropout(0.2))

# model.add(Dense(64, activation='relu'))
# model.add(Dropout(0.2))
# model.add(Dense(32, activation='relu'))
# # Output layer
# model.add(Dense(1, activation='linear'))

# model.compile(loss='mse',optimizer='adam',metrics=['mae','mse',r_squared])
# model.summary()

# %%
from tensorflow.keras.callbacks import EarlyStopping

# Early stopping to stop training when a monitored metric has stopped improving
early_stop = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

# Train the model
history = model.fit(X_train, y_train, 
                    epochs=30, 
                    batch_size=4, 
                    # validation_split=0.1, )            
                    validation_data=(X_test, y_test), )
                    # callbacks=[early_stop])
# Out:
# Epoch 1/30
# 1999/1999 [==============================] - 20s 9ms/step - loss: 0.0781 - mae: 0.2160 - mse: 0.0781 - val_loss: 0.0160 - val_mae: 0.0842 - val_mse: 0.0160
# Epoch 2/30
# 1999/1999 [==============================] - 20s 10ms/step - loss: 0.0277 - mae: 0.1211 - mse: 0.0277 - val_loss: 0.0129 - val_mae: 0.0681 - val_mse: 0.0129
# Epoch 3/30
# 1999/1999 [==============================] - 20s 10ms/step - loss: 0.0219 - mae: 0.1050 - mse: 0.0219 - val_loss: 0.0125 - val_mae: 0.0718 - val_mse: 0.0125
# Epoch 4/30
# 1999/1999 [==============================] - 24s 12ms/step - loss: 0.0181 - mae: 0.0930 - mse: 0.0181 - val_loss: 0.0118 - val_mae: 0.0666 - val_mse: 0.0118
# Epoch 5/30
# 1999/1999 [==============================] - 25s 12ms/step - loss: 0.0164 - mae: 0.0880 - mse: 0.0164 - val_loss: 0.0110 - val_mae: 0.0562 - val_mse: 0.0110
# Epoch 6/30
# 1999/1999 [==============================] - 24s 12ms/step - loss: 0.0151 - mae: 0.0836 - mse: 0.0151 - val_loss: 0.0115 - val_mae: 0.0632 - val_mse: 0.0115
# Epoch 7/30
# 1999/1999 [==============================] - 25s 12ms/step - loss: 0.0142 - mae: 0.0797 - mse: 0.0142 - val_loss: 0.0105 - val_mae: 0.0692 - val_mse: 0.0105
# Epoch 8/30
# 1999/1999 [==============================] - 25s 13ms/step - loss: 0.0129 - mae: 0.0768 - mse: 0.0129 - val_loss: 0.0087 - val_mae: 0.0504 - val_mse: 0.0087
# Epoch 9/30
# 1999/1999 [==============================] - 24s 12ms/step - loss: 0.0123 - mae: 0.0742 - mse: 0.0123 - val_loss: 0.0083 - val_mae: 0.0521 - val_mse: 0.0083
# Epoch 10/30
# 1999/1999 [==============================] - 25s 13ms/step - loss: 0.0114 - mae: 0.0712 - mse: 0.0114 - val_loss: 0.0077 - val_mae: 0.0499 - val_mse: 0.0077
# Epoch 11/30
# 1999/1999 [==============================] - 21s 11ms/step - loss: 0.0108 - mae: 0.0694 - mse: 0.0108 - val_loss: 0.0092 - val_mae: 0.0674 - val_mse: 0.0092
# Epoch 12/30
# 1999/1999 [==============================] - 21s 10ms/step - loss: 0.0105 - mae: 0.0685 - mse: 0.0105 - val_loss: 0.0073 - val_mae: 0.0454 - val_mse: 0.0073
# Epoch 13/30
# 1999/1999 [==============================] - 21s 10ms/step - loss: 0.0102 - mae: 0.0672 - mse: 0.0102 - val_loss: 0.0069 - val_mae: 0.0458 - val_mse: 0.0069
# Epoch 14/30
# 1999/1999 [==============================] - 21s 10ms/step - loss: 0.0099 - mae: 0.0653 - mse: 0.0099 - val_loss: 0.0077 - val_mae: 0.0507 - val_mse: 0.0077
# Epoch 15/30
# 1999/1999 [==============================] - 21s 11ms/step - loss: 0.0097 - mae: 0.0652 - mse: 0.0097 - val_loss: 0.0064 - val_mae: 0.0472 - val_mse: 0.0064
# Epoch 16/30
# 1999/1999 [==============================] - 24s 12ms/step - loss: 0.0091 - mae: 0.0636 - mse: 0.0091 - val_loss: 0.0067 - val_mae: 0.0434 - val_mse: 0.0067
# Epoch 17/30
# 1999/1999 [==============================] - 21s 11ms/step - loss: 0.0091 - mae: 0.0624 - mse: 0.0091 - val_loss: 0.0062 - val_mae: 0.0410 - val_mse: 0.0062
# Epoch 18/30
# 1999/1999 [==============================] - 23s 12ms/step - loss: 0.0088 - mae: 0.0618 - mse: 0.0088 - val_loss: 0.0059 - val_mae: 0.0398 - val_mse: 0.0059
# Epoch 19/30
# 1999/1999 [==============================] - 21s 11ms/step - loss: 0.0085 - mae: 0.0608 - mse: 0.0085 - val_loss: 0.0061 - val_mae: 0.0491 - val_mse: 0.0061
# Epoch 20/30
# 1999/1999 [==============================] - 23s 11ms/step - loss: 0.0084 - mae: 0.0602 - mse: 0.0084 - val_loss: 0.0060 - val_mae: 0.0412 - val_mse: 0.0060
# Epoch 21/30
# 1999/1999 [==============================] - 22s 11ms/step - loss: 0.0083 - mae: 0.0597 - mse: 0.0083 - val_loss: 0.0073 - val_mae: 0.0544 - val_mse: 0.0073
# Epoch 22/30
# 1999/1999 [==============================] - 23s 12ms/step - loss: 0.0080 - mae: 0.0588 - mse: 0.0080 - val_loss: 0.0054 - val_mae: 0.0391 - val_mse: 0.0054
# Epoch 23/30
# 1999/1999 [==============================] - 21s 11ms/step - loss: 0.0078 - mae: 0.0577 - mse: 0.0078 - val_loss: 0.0053 - val_mae: 0.0384 - val_mse: 0.0053
# Epoch 24/30
# 1999/1999 [==============================] - 23s 11ms/step - loss: 0.0077 - mae: 0.0570 - mse: 0.0077 - val_loss: 0.0056 - val_mae: 0.0418 - val_mse: 0.0056
# Epoch 25/30
# 1999/1999 [==============================] - 21s 11ms/step - loss: 0.0076 - mae: 0.0565 - mse: 0.0076 - val_loss: 0.0057 - val_mae: 0.0494 - val_mse: 0.0057
# Epoch 26/30
# 1999/1999 [==============================] - 22s 11ms/step - loss: 0.0077 - mae: 0.0570 - mse: 0.0077 - val_loss: 0.0055 - val_mae: 0.0454 - val_mse: 0.0055
# Epoch 27/30
# 1999/1999 [==============================] - 21s 10ms/step - loss: 0.0076 - mae: 0.0565 - mse: 0.0076 - val_loss: 0.0051 - val_mae: 0.0377 - val_mse: 0.0051
# Epoch 28/30
# 1999/1999 [==============================] - 22s 11ms/step - loss: 0.0075 - mae: 0.0562 - mse: 0.0075 - val_loss: 0.0053 - val_mae: 0.0381 - val_mse: 0.0053
# Epoch 29/30
# 1999/1999 [==============================] - 21s 10ms/step - loss: 0.0073 - mae: 0.0557 - mse: 0.0073 - val_loss: 0.0058 - val_mae: 0.0491 - val_mse: 0.0058
# Epoch 30/30
# 1999/1999 [==============================] - 21s 11ms/step - loss: 0.0075 - mae: 0.0553 - mse: 0.0075 - val_loss: 0.0050 - val_mae: 0.0391 - val_mse: 0.0050

# %%
# # Predict on test set
# predictions = model.predict(X_test)

# # Rescale the predictions and actual values to their original scale if needed
# y_test_rescaled = scaler.inverse_transform(y_test.reshape(-1, 1))
# predictions_rescaled = scaler.inverse_transform(predictions)

# # Calculate error metrics
# from sklearn.metrics import mean_squared_error
# mse = mean_squared_error(y_test_rescaled, predictions_rescaled)
# print("Mean Squared Error:", mse)

# %%
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error, mean_absolute_error
result=model.predict(X_test)
result
# Out:
# array([[0.94397163],
#        [0.9439776 ],
#        [0.9439813 ],
#        ...,
#        [0.46285057],
#        [0.46185654],
#        [0.45686716]], dtype=float32)

# %%
r2=r2_score(y_test,result)
print(f'R2 score:{r2*100:2f}')
#0.8641384950615951
# Out:
# R2 score:94.156385

# %%
# 2. Calculate Mean Squared Error (MSE)
mse = mean_squared_error(y_test, result)

# 3. Calculate Mean Absolute Error (MAE)
mae = mean_absolute_error(y_test, result)

print(f"Mean Squared Error (MSE): {mse}")
print(f"Mean Absolute Error (MAE): {mae}")
# Out:
# Mean Squared Error (MSE): 0.009956178097557375
# Mean Absolute Error (MAE): 0.05832500103856604

# %%
real_y_test = scaler_02.inverse_transform(y_test)
real_results = scaler_02.inverse_transform(result)

r2=r2_score(real_y_test,real_results)
print('R2 score:',r2)

# 2. Calculate Mean Squared Error (MSE)
mse = mean_squared_error(real_y_test, real_results)

# 3. Calculate Mean Absolute Error (MAE)
mae = mean_absolute_error(real_y_test, real_results)

print(f"Mean Squared Error (MSE): {mse}")
print(f"Mean Absolute Error (MAE): {mae}")
# Out:
# R2 score: 0.9415638531926629
# Mean Squared Error (MSE): 129622.66342326126
# Mean Absolute Error (MAE): 210.44996818010813

# %%
test_x_range=np.arange(train_size ,len(X),1)
plt.figure(figsize=(16,6))
plt.plot(y_train,'r',label='train')
plt.plot(test_x_range,y_test,'b',label='Test')
plt.plot(test_x_range,result,'g',label='Predicted')

plt.xlabel('Date')
plt.ylabel('Power Curve (Scaled)')
plt.legend()
plt.show()

# %%
test_x_range=np.arange(train_size ,len(X),1)
plt.figure(figsize=(16,6))
# plt.plot(y_train,'r',label='train')
plt.plot(test_x_range,y_test,'b',label='Test')
plt.plot(test_x_range,result-0.00,'g',label='Predicted')
plt.xlabel('Date')
plt.ylabel('Power Curve (Scaled)')
plt.legend()
plt.show()

# %%
from matplotlib import pyplot as plt
import seaborn as sns

plt.figure(figsize=(12, 8))

# plt.subplot(2, 2, 4)
# plt.plot(history.history["r_squared"],label='R2')
# plt.plot(history.history["val_r_squared"],label='Val R2')
# plt.legend()
# plt.ylabel('R2')
# plt.xlabel('# Epoch')
# plt.title('R2 Score')

plt.subplot(2, 2, 1)
plt.plot(history.history['loss'],label='Loss')
plt.plot(history.history['val_loss'],label='Val Loss')
plt.legend()
plt.xlabel('# Epoch')
plt.ylabel('Loss')
plt.title('Losses')

plt.subplot(2, 2, 4)
plt.plot(history.history['mse'],label='MSE')
plt.plot(history.history['val_mse'],label='Val MSE')
plt.legend()
plt.ylabel('Error')
plt.xlabel('# Epoch')
plt.title('MSE')

plt.subplot(2, 2, 3)
plt.plot(history.history["mae"],label='MAE')
plt.plot(history.history["val_mae"],label='Val MAE')
plt.legend()
plt.ylabel('Evaluation')
plt.xlabel('# Epoch')
plt.title('MAE')

plt.tight_layout(pad=1)
# plt.savefig("Results.png")
# plt.show()

# x = model.evaluate(test_data, test_target)
# print("\n",round(x[1]*100,2),"%")

# %%
from sklearn.metrics import mean_absolute_error
import numpy as np

# Define a function for permutation importance
def permutation_importance(model, X_test, y_test):
    baseline = mean_absolute_error(y_test, model.predict(X_test))
    importances = []
    
    for i in range(X_test.shape[2]):  # Iterate over features
        X_permuted = X_test.copy()
        np.random.shuffle(X_permuted[:, :, i])  # Shuffle the ith feature
        permuted_mae = mean_absolute_error(y_test, model.predict(X_permuted))
        importance = permuted_mae - baseline  # Compute importance as the drop in performance
        importances.append(importance)
    
    return np.array(importances)

# Example usage:
feature_importances = permutation_importance(model, X_test, y_test)
print("Feature importances:", feature_importances)
# Out:
# Feature importances: [ 3.36135443e-01  4.79686557e-03  1.84745266e-02 -1.87031899e-04
#   0.00000000e+00  5.94716754e-04 -1.38353209e-03 -3.65301425e-04
#  -1.46690884e-04]

# %%
for i in feature_importances:
    print(i * 100)
# Out:
# 33.61354426606117
# 0.4796865572330167
# 1.8474526551790647
# -0.01870318988408115
# 0.0
# 0.059471675367918364
# -0.1383532090176165
# -0.03653014253109238
# -0.014669088385314832
